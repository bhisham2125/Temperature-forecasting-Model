# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %%
temp = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv')
temp
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 1       90.604721         29.850689         24.035009   5.691890   51.937448
# 2       83.973587         30.091292         24.565633   6.138224   20.573050
# 3       96.483688         29.704629         23.326177   5.650050   65.727144
# 4       90.155128         29.113934         23.486480   5.735004  107.965535
# ...           ...               ...               ...        ...         ...
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 1     ...    0.000000    0.000000    0.000000  37.6046  127.032   44.7624
# 2     ...    0.000000    0.000000    0.000000  37.5776  127.058   33.3068
# 3     ...    0.000000    0.000000    0.000000  37.6450  127.022   45.7160
# 4     ...    0.000000    0.000000    0.000000  37.5507  127.135   35.0380
# ...   ...         ...         ...         ...      ...      ...       ...
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 1     0.514100      5869.312500       30.5       22.5
# 2     0.266100      5863.555664       31.1       23.9
# 3     2.534800      5856.964844       31.7       24.3
# 4     0.505500      5859.552246       31.2       22.5
# ...        ...              ...        ...        ...
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %%
# Checking the shape of the dataset-
temp.shape
# Out:
# (7752, 25)

# %%
# Checking the names of all the columns- 
temp.columns.to_list()
# Out:
# ['station',
#  'Date',
#  'Present_Tmax',
#  'Present_Tmin',
#  'LDAPS_RHmin',
#  'LDAPS_RHmax',
#  'LDAPS_Tmax_lapse',
#  'LDAPS_Tmin_lapse',
#  'LDAPS_WS',
#  'LDAPS_LH',
#  'LDAPS_CC1',
#  'LDAPS_CC2',
#  'LDAPS_CC3',
#  'LDAPS_CC4',
#  'LDAPS_PPT1',
#  'LDAPS_PPT2',
#  'LDAPS_PPT3',
#  'LDAPS_PPT4',
#  'lat',
#  'lon',
#  'DEM',
#  'Slope',
#  'Solar radiation',
#  'Next_Tmax',
#  'Next_Tmin']

# %%
# checking the datatypes of all the columns 
temp.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# All the data is in float datatype , except 'Date' which is a object datatype.

# %%
# Checking the info of the features in the dataset-
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
#  16  LDAPS_PPT3        7677 non-null   float64
#  17  LDAPS_PPT4        7677 non-null   float64
#  18  lat               7752 non-null   float64
#  19  lon               7752 non-null   float64
#  20  DEM               7752 non-null   float64
#  21  Slope             7752 non-null   float64
#  22  Solar radiation   7752 non-null   float64
#  23  Next_Tmax         7725 non-null   float64
#  24  Next_Tmin         7725 non-null   float64
# dtypes: float64(24), object(1)
# memory usage: 1.5+ MB

# %%
#STATISTICAL SUMMARY-
temp.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# min           17.624954         14.272646     2.882580   -13.603212
# 25%           27.673499         22.089739     5.678705    37.266753
# 50%           29.703426         23.760199     6.547470    56.865482
# 75%           31.710450         25.152909     8.032276    84.223616
# max           38.542255         29.619342    21.857621   213.414006
#
#          LDAPS_CC1  ...   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  7677.000000  ...  7677.000000  7677.000000  7677.000000  7752.000000
# mean      0.368774  ...     0.485003     0.278200     0.269407    37.544722
# std       0.262458  ...     1.762807     1.161809     1.206214     0.050352
# min       0.000000  ...     0.000000     0.000000     0.000000    37.456200
# 25%       0.146654  ...     0.000000     0.000000     0.000000    37.510200
# 50%       0.315697  ...     0.000000     0.000000     0.000000    37.550700
# 75%       0.575489  ...     0.018364     0.007896     0.000041    37.577600
# max       0.967277  ...    21.621661    15.841235    16.655469    37.645000
#
#                lon          DEM        Slope  Solar radiation    Next_Tmax  \
# count  7752.000000  7752.000000  7752.000000      7752.000000  7725.000000
# mean    126.991397    61.867972     1.257048      5341.502803    30.274887
# std       0.079435    54.279780     1.370444       429.158867     3.128010
# min     126.826000    12.370000     0.098475      4329.520508    17.400000
# 25%     126.937000    28.700000     0.271300      4999.018555    28.200000
# 50%     126.995000    45.716000     0.618000      5436.345215    30.500000
# 75%     127.042000    59.832400     1.767800      5728.316406    32.600000
# max     127.135000   212.335000     5.178230      5992.895996    38.900000
#
#          Next_Tmin
# count  7725.000000
# mean     22.932220
# std       2.487613
# min      11.300000
# 25%      21.300000
# 50%      23.100000
# 75%      24.600000
# max      29.800000
#
# [8 rows x 24 columns]

# %%
temp.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
plt.figure(figsize=[12,8])
sns.heatmap(temp.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# white lines represent the null values in our data .

# %%
temp.duplicated().sum()
# Out:
# 0

# %%
# convering the date into datetime format.
temp['Date']=pd.to_datetime(temp['Date'])

# %%
for col in temp.columns:
    temp[col]= temp[col].replace(np.nan,temp[col].median())

# %%
temp.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
temp
# Out:
#       station                Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0 2013-06-30 00:00:00          28.7          21.4    58.255688
# 1         2.0 2013-06-30 00:00:00          31.9          21.6    52.263397
# 2         3.0 2013-06-30 00:00:00          31.6          23.3    48.690479
# 3         4.0 2013-06-30 00:00:00          32.0          23.4    58.239788
# 4         5.0 2013-06-30 00:00:00          31.4          21.9    56.174095
# ...       ...                 ...           ...           ...          ...
# 7747     23.0 2017-08-30 00:00:00          23.3          17.1    26.741310
# 7748     24.0 2017-08-30 00:00:00          23.3          17.7    24.040634
# 7749     25.0 2017-08-30 00:00:00          23.2          17.4    22.933014
# 7750     13.0 2015-07-28 12:00:00          20.0          11.3    19.794666
# 7751     13.0 2015-07-28 12:00:00          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 1       90.604721         29.850689         24.035009   5.691890   51.937448
# 2       83.973587         30.091292         24.565633   6.138224   20.573050
# 3       96.483688         29.704629         23.326177   5.650050   65.727144
# 4       90.155128         29.113934         23.486480   5.735004  107.965535
# ...           ...               ...               ...        ...         ...
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 1     ...    0.000000    0.000000    0.000000  37.6046  127.032   44.7624
# 2     ...    0.000000    0.000000    0.000000  37.5776  127.058   33.3068
# 3     ...    0.000000    0.000000    0.000000  37.6450  127.022   45.7160
# 4     ...    0.000000    0.000000    0.000000  37.5507  127.135   35.0380
# ...   ...         ...         ...         ...      ...      ...       ...
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 1     0.514100      5869.312500       30.5       22.5
# 2     0.266100      5863.555664       31.1       23.9
# 3     2.534800      5856.964844       31.7       24.3
# 4     0.505500      5859.552246       31.2       22.5
# ...        ...              ...        ...        ...
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %%
temp[temp.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [station, Date, Present_Tmax, Present_Tmin, LDAPS_RHmin, LDAPS_RHmax, LDAPS_Tmax_lapse, LDAPS_Tmin_lapse, LDAPS_WS, LDAPS_LH, LDAPS_CC1, LDAPS_CC2, LDAPS_CC3, LDAPS_CC4, LDAPS_PPT1, LDAPS_PPT2, LDAPS_PPT3, LDAPS_PPT4, lat, lon, DEM, Slope, Solar radiation, Next_Tmax, Next_Tmin]
# Index: []
#
# [0 rows x 25 columns]

# %%
temp.nunique()
# Out:
# station               25
# Date                 311
# Present_Tmax         167
# Present_Tmin         155
# LDAPS_RHmin         7672
# LDAPS_RHmax         7664
# LDAPS_Tmax_lapse    7675
# LDAPS_Tmin_lapse    7675
# LDAPS_WS            7675
# LDAPS_LH            7675
# LDAPS_CC1           7569
# LDAPS_CC2           7582
# LDAPS_CC3           7599
# LDAPS_CC4           7524
# LDAPS_PPT1          2812
# LDAPS_PPT2          2510
# LDAPS_PPT3          2356
# LDAPS_PPT4          1918
# lat                   12
# lon                   25
# DEM                   25
# Slope                 27
# Solar radiation     1575
# Next_Tmax            183
# Next_Tmin            157
# dtype: int64

# %%
temp.shape
# Out:
# (7752, 25)

# %%
temp.corr()
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.112582      0.131525    -0.066729
# Present_Tmax      0.112582      1.000000      0.618769    -0.205341
# Present_Tmin      0.131525      0.618769      1.000000     0.121800
# LDAPS_RHmin      -0.066729     -0.205341      0.121800     1.000000
# LDAPS_RHmax      -0.166953     -0.300261     -0.012659     0.578770
# LDAPS_Tmax_lapse  0.069107      0.570287      0.464420    -0.564575
# LDAPS_Tmin_lapse  0.104753      0.624229      0.764239     0.089346
# LDAPS_WS          0.005275     -0.123565     -0.037682     0.294537
# LDAPS_LH         -0.133339      0.134216     -0.011331    -0.070654
# LDAPS_CC1         0.006917     -0.313176      0.082000     0.613885
# LDAPS_CC2         0.003396     -0.214904      0.088309     0.745482
# LDAPS_CC3         0.000694     -0.145477     -0.005304     0.689720
# LDAPS_CC4         0.006124     -0.142549     -0.047496     0.514163
# LDAPS_PPT1       -0.002708     -0.111148      0.109085     0.262875
# LDAPS_PPT2       -0.008247     -0.101362      0.064851     0.391110
# LDAPS_PPT3       -0.012458     -0.122051     -0.049017     0.240831
# LDAPS_PPT4       -0.010399     -0.101118     -0.065550     0.168797
# lat              -0.237502     -0.052659     -0.078547     0.087093
# lon              -0.118704      0.008990     -0.043509    -0.076232
# DEM              -0.255830     -0.187138     -0.250299     0.102108
# Slope            -0.090061     -0.105884     -0.146460     0.123736
# Solar radiation  -0.019001     -0.025401      0.053638     0.244643
# Next_Tmax         0.107900      0.610256      0.471723    -0.439171
# Next_Tmin         0.128216      0.622700      0.796657     0.094061
#
#                   LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  \
# station             -0.166953          0.069107          0.104753  0.005275
# Present_Tmax        -0.300261          0.570287          0.624229 -0.123565
# Present_Tmin        -0.012659          0.464420          0.764239 -0.037682
# LDAPS_RHmin          0.578770         -0.564575          0.089346  0.294537
# LDAPS_RHmax          1.000000         -0.373274         -0.113914  0.134786
# LDAPS_Tmax_lapse    -0.373274          1.000000          0.654013 -0.311973
# LDAPS_Tmin_lapse    -0.113914          0.654013          1.000000 -0.130245
# LDAPS_WS             0.134786         -0.311973         -0.130245  1.000000
# LDAPS_LH             0.238183          0.047954         -0.134906  0.007115
# LDAPS_CC1            0.436097         -0.438410          0.010691  0.289792
# LDAPS_CC2            0.390879         -0.523594          0.047545  0.261386
# LDAPS_CC3            0.226434         -0.541260         -0.044233  0.243402
# LDAPS_CC4            0.130008         -0.429456         -0.080587  0.221066
# LDAPS_PPT1           0.267698         -0.111105          0.037727  0.153213
# LDAPS_PPT2           0.228398         -0.242113          0.000588  0.192427
# LDAPS_PPT3           0.134087         -0.188133         -0.088791  0.162173
# LDAPS_PPT4           0.117376         -0.160300         -0.094855  0.144550
# lat                  0.195761         -0.042093         -0.096252  0.036646
# lon                  0.025662          0.090665         -0.026700 -0.059448
# DEM                  0.177134         -0.178895         -0.195445  0.190995
# Slope                0.219557         -0.162332         -0.185839  0.171577
# Solar radiation      0.148259          0.047820          0.159445  0.122966
# Next_Tmax           -0.281282          0.827473          0.588224 -0.345578
# Next_Tmin           -0.070193          0.587066          0.881074 -0.098730
#
#                   LDAPS_LH  LDAPS_CC1  ...  LDAPS_PPT2  LDAPS_PPT3  \
# station          -0.133339   0.006917  ...   -0.008247   -0.012458
# Present_Tmax      0.134216  -0.313176  ...   -0.101362   -0.122051
# Present_Tmin     -0.011331   0.082000  ...    0.064851   -0.049017
# LDAPS_RHmin      -0.070654   0.613885  ...    0.391110    0.240831
# LDAPS_RHmax       0.238183   0.436097  ...    0.228398    0.134087
# LDAPS_Tmax_lapse  0.047954  -0.438410  ...   -0.242113   -0.188133
# LDAPS_Tmin_lapse -0.134906   0.010691  ...    0.000588   -0.088791
# LDAPS_WS          0.007115   0.289792  ...    0.192427    0.162173
# LDAPS_LH          1.000000  -0.146920  ...   -0.077061    0.016483
# LDAPS_CC1        -0.146920   1.000000  ...    0.389771    0.169130
# LDAPS_CC2        -0.263934   0.779752  ...    0.478681    0.240426
# LDAPS_CC3        -0.245130   0.517702  ...    0.337958    0.340141
# LDAPS_CC4        -0.172222   0.361386  ...    0.288728    0.267968
# LDAPS_PPT1       -0.012042   0.446635  ...    0.384329    0.033685
# LDAPS_PPT2       -0.077061   0.389771  ...    1.000000    0.221667
# LDAPS_PPT3        0.016483   0.169130  ...    0.221667    1.000000
# LDAPS_PPT4        0.020332   0.092119  ...    0.140064    0.309433
# lat               0.133203  -0.008129  ...    0.019557    0.035101
# lon               0.025819  -0.006842  ...    0.018593    0.021656
# DEM               0.055126  -0.014087  ...    0.008354    0.017182
# Slope             0.086770  -0.020747  ...    0.010211    0.025327
# Solar radiation  -0.046553   0.219264  ...    0.111500   -0.052874
# Next_Tmax         0.155684  -0.454771  ...   -0.181556   -0.196866
# Next_Tmin        -0.056832  -0.012732  ...   -0.010451   -0.064651
#
#                   LDAPS_PPT4       lat       lon       DEM     Slope  \
# station            -0.010399 -0.237502 -0.118704 -0.255830 -0.090061
# Present_Tmax       -0.101118 -0.052659  0.008990 -0.187138 -0.105884
# Present_Tmin       -0.065550 -0.078547 -0.043509 -0.250299 -0.146460
# LDAPS_RHmin         0.168797  0.087093 -0.076232  0.102108  0.123736
# LDAPS_RHmax         0.117376  0.195761  0.025662  0.177134  0.219557
# LDAPS_Tmax_lapse   -0.160300 -0.042093  0.090665 -0.178895 -0.162332
# LDAPS_Tmin_lapse   -0.094855 -0.096252 -0.026700 -0.195445 -0.185839
# LDAPS_WS            0.144550  0.036646 -0.059448  0.190995  0.171577
# LDAPS_LH            0.020332  0.133203  0.025819  0.055126  0.086770
# LDAPS_CC1           0.092119 -0.008129 -0.006842 -0.014087 -0.020747
# LDAPS_CC2           0.159853 -0.001497 -0.003581 -0.012821 -0.018070
# LDAPS_CC3           0.302693  0.004107  0.016037  0.000698 -0.003337
# LDAPS_CC4           0.376422 -0.009103 -0.002476 -0.007331 -0.014453
# LDAPS_PPT1          0.025266  0.000565 -0.001225  0.011286  0.016303
# LDAPS_PPT2          0.140064  0.019557  0.018593  0.008354  0.010211
# LDAPS_PPT3          0.309433  0.035101  0.021656  0.017182  0.025327
# LDAPS_PPT4          1.000000  0.013207  0.044735 -0.003621  0.000118
# lat                 0.013207  1.000000  0.289029  0.033165  0.074763
# lon                 0.044735  0.289029  1.000000  0.007587  0.038070
# DEM                -0.003621  0.033165  0.007587  1.000000  0.783576
# Slope               0.000118  0.074763  0.038070  0.783576  1.000000
# Solar radiation     0.036052  0.038513  0.002182  0.056224  0.028199
# Next_Tmax          -0.181329 -0.053557  0.003076 -0.172614 -0.102812
# Next_Tmin          -0.105625 -0.083577 -0.046580 -0.246977 -0.146963
#
#                   Solar radiation  Next_Tmax  Next_Tmin
# station                 -0.019001   0.107900   0.128216
# Present_Tmax            -0.025401   0.610256   0.622700
# Present_Tmin             0.053638   0.471723   0.796657
# LDAPS_RHmin              0.244643  -0.439171   0.094061
# LDAPS_RHmax              0.148259  -0.281282  -0.070193
# LDAPS_Tmax_lapse         0.047820   0.827473   0.587066
# LDAPS_Tmin_lapse         0.159445   0.588224   0.881074
# LDAPS_WS                 0.122966  -0.345578  -0.098730
# LDAPS_LH                -0.046553   0.155684  -0.056832
# LDAPS_CC1                0.219264  -0.454771  -0.012732
# LDAPS_CC2                0.171215  -0.492615   0.029829
# LDAPS_CC3                0.120365  -0.517125  -0.056604
# LDAPS_CC4                0.121326  -0.449457  -0.087510
# LDAPS_PPT1               0.089477  -0.122365   0.018645
# LDAPS_PPT2               0.111500  -0.181556  -0.010451
# LDAPS_PPT3              -0.052874  -0.196866  -0.064651
# LDAPS_PPT4               0.036052  -0.181329  -0.105625
# lat                      0.038513  -0.053557  -0.083577
# lon                      0.002182   0.003076  -0.046580
# DEM                      0.056224  -0.172614  -0.246977
# Slope                    0.028199  -0.102812  -0.146963
# Solar radiation          1.000000   0.008701   0.120122
# Next_Tmax                0.008701   1.000000   0.621434
# Next_Tmin                0.120122   0.621434   1.000000
#
# [24 rows x 24 columns]

# %%
plt.figure(figsize=[15,10])
sns.heatmap(temp.corr(),annot = True, fmt ='0.2f', cmap="PiYG")
# Out:
# <AxesSubplot:>

# %%
temp.corr()[["Next_Tmax", "Next_Tmin"]]
# Out:
#                   Next_Tmax  Next_Tmin
# station            0.107900   0.128216
# Present_Tmax       0.610256   0.622700
# Present_Tmin       0.471723   0.796657
# LDAPS_RHmin       -0.439171   0.094061
# LDAPS_RHmax       -0.281282  -0.070193
# LDAPS_Tmax_lapse   0.827473   0.587066
# LDAPS_Tmin_lapse   0.588224   0.881074
# LDAPS_WS          -0.345578  -0.098730
# LDAPS_LH           0.155684  -0.056832
# LDAPS_CC1         -0.454771  -0.012732
# LDAPS_CC2         -0.492615   0.029829
# LDAPS_CC3         -0.517125  -0.056604
# LDAPS_CC4         -0.449457  -0.087510
# LDAPS_PPT1        -0.122365   0.018645
# LDAPS_PPT2        -0.181556  -0.010451
# LDAPS_PPT3        -0.196866  -0.064651
# LDAPS_PPT4        -0.181329  -0.105625
# lat               -0.053557  -0.083577
# lon                0.003076  -0.046580
# DEM               -0.172614  -0.246977
# Slope             -0.102812  -0.146963
# Solar radiation    0.008701   0.120122
# Next_Tmax          1.000000   0.621434
# Next_Tmin          0.621434   1.000000

# %%
features=temp[['station',
              'Present_Tmax','Present_Tmin','LDAPS_RHmin','LDAPS_RHmax','LDAPS_Tmax_lapse',
              'LDAPS_Tmin_lapse','LDAPS_WS','LDAPS_LH','LDAPS_CC1','LDAPS_CC2','LDAPS_CC3','LDAPS_CC4','LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT4','lat','lon','DEM','Slope','Solar radiation','Next_Tmax','Next_Tmin']]

# %%
plt.figure(figsize=(20,25),facecolor='lightyellow')
pltnum=1
for col in features:
    if pltnum<=25:
        plt.subplot(5,5,pltnum)
        sns.distplot(features[col],color='green')
        plt.xlabel(col,fontsize=20)
    pltnum+=1
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
for i in features.columns:                                   
    plt.figure(figsize = (8, 5))
    sns.regplot(x=features[i],y= features['Next_Tmax'])
    plt.title(' Next Tmax vs other attributes')
    plt.xlabel(i)
    plt.ylabel('Next Max Temperature')
    plt.show()

# %% [markdown]
# 'Next_Tmin' is positive relationship with Present max , Present T_min,LDAPS_Tmax_Lapse,LDAPS_Tmin_Lapse and Next_Tmax, while negatively relationship with DEM,Slope and LDAPS_pp4

# %%
#Checking for outliers -
temp.plot(kind='box',subplots=True,layout=(6,5),figsize=(16,12))
# Out:
# station                 AxesSubplot(0.125,0.77;0.133621x0.11)
# Present_Tmax         AxesSubplot(0.285345,0.77;0.133621x0.11)
# Present_Tmin          AxesSubplot(0.44569,0.77;0.133621x0.11)
# LDAPS_RHmin          AxesSubplot(0.606034,0.77;0.133621x0.11)
# LDAPS_RHmax          AxesSubplot(0.766379,0.77;0.133621x0.11)
# LDAPS_Tmax_lapse       AxesSubplot(0.125,0.638;0.133621x0.11)
# LDAPS_Tmin_lapse    AxesSubplot(0.285345,0.638;0.133621x0.11)
# LDAPS_WS             AxesSubplot(0.44569,0.638;0.133621x0.11)
# LDAPS_LH            AxesSubplot(0.606034,0.638;0.133621x0.11)
# LDAPS_CC1           AxesSubplot(0.766379,0.638;0.133621x0.11)
# LDAPS_CC2              AxesSubplot(0.125,0.506;0.133621x0.11)
# LDAPS_CC3           AxesSubplot(0.285345,0.506;0.133621x0.11)
# LDAPS_CC4            AxesSubplot(0.44569,0.506;0.133621x0.11)
# LDAPS_PPT1          AxesSubplot(0.606034,0.506;0.133621x0.11)
# LDAPS_PPT2          AxesSubplot(0.766379,0.506;0.133621x0.11)
# LDAPS_PPT3             AxesSubplot(0.125,0.374;0.133621x0.11)
# LDAPS_PPT4          AxesSubplot(0.285345,0.374;0.133621x0.11)
# lat                  AxesSubplot(0.44569,0.374;0.133621x0.11)
# lon                 AxesSubplot(0.606034,0.374;0.133621x0.11)
# DEM                 AxesSubplot(0.766379,0.374;0.133621x0.11)
# Slope                  AxesSubplot(0.125,0.242;0.133621x0.11)
# Solar radiation     AxesSubplot(0.285345,0.242;0.133621x0.11)
# Next_Tmax            AxesSubplot(0.44569,0.242;0.133621x0.11)
# Next_Tmin           AxesSubplot(0.606034,0.242;0.133621x0.11)
# dtype: object

# %%
temp.skew().sort_values(ascending = False)
# Out:
# LDAPS_PPT4          6.826930
# LDAPS_PPT3          6.458608
# LDAPS_PPT2          5.776835
# LDAPS_PPT1          5.395178
# DEM                 1.723257
# LDAPS_WS            1.584975
# Slope               1.563020
# LDAPS_LH            0.678315
# LDAPS_CC4           0.673700
# LDAPS_CC3           0.646670
# LDAPS_CC2           0.477041
# LDAPS_CC1           0.465003
# LDAPS_RHmin         0.303565
# lat                 0.087062
# station             0.000000
# LDAPS_Tmax_lapse   -0.228767
# Present_Tmax       -0.265337
# lon                -0.285213
# Next_Tmax          -0.340943
# Present_Tmin       -0.369481
# Next_Tmin          -0.405143
# Solar radiation    -0.511210
# LDAPS_Tmin_lapse   -0.584737
# LDAPS_RHmax        -0.860210
# dtype: float64

# %% [markdown]
# columns 'station','LDAPS_RHmin 'LDAPS_CC1','LDAPS_CC2','LDAPS_CC3',LDAPS_CC4,lat,lon,DEM,Slope,Solar radiation do not have any outliers , while Present_Tmax,Present_Tmin,'LDAPS_RHmax,LDAPS_Tmaxlapse,LDAPS_Tmin_lapse,LDAPS_WS,LDAPS_LH,LDAPS_PP1,LDAPS_PP2,LDAPS_PP3,LDAPS_PP4,Next_tmax,Next_tmin does have outliers in them .

# %%
#removing skewness
import datetime as ddt

temp['Date'] = pd.to_datetime(temp['Date'])
temp['Date'] = temp['Date'].map(ddt.datetime.toordinal)

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()

for i in temp.columns:
    if abs(temp.loc[:,i].skew())>0.5:
        temp.loc[:,i]=pt.fit_transform(temp.loc[:,i].values.reshape(-1,1))

# %%
temp.skew().sort_values(ascending = False)
# Out:
# LDAPS_PPT4          2.059400
# LDAPS_PPT3          1.824919
# LDAPS_PPT2          1.646417
# LDAPS_PPT1          1.463941
# LDAPS_CC2           0.477041
# LDAPS_CC1           0.465003
# LDAPS_RHmin         0.303565
# Slope               0.233968
# LDAPS_CC4           0.129826
# LDAPS_CC3           0.089672
# lat                 0.087062
# LDAPS_LH            0.058865
# DEM                 0.039456
# LDAPS_WS            0.002449
# station             0.000000
# Date               -0.001692
# LDAPS_Tmin_lapse   -0.018120
# LDAPS_RHmax        -0.116481
# Solar radiation    -0.176636
# LDAPS_Tmax_lapse   -0.228767
# Present_Tmax       -0.265337
# lon                -0.285213
# Next_Tmax          -0.340943
# Present_Tmin       -0.369481
# Next_Tmin          -0.405143
# dtype: float64

# %%
#removing outliers
from scipy.stats import zscore
z=np.abs(zscore(temp))
temp_new=temp[(z<3).all(axis=1)]
temp_new
# Out:
#       station    Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0  735049          28.7          21.4    58.255688     0.269762
# 1         2.0  735049          31.9          21.6    52.263397     0.182577
# 2         3.0  735049          31.6          23.3    48.690479    -0.776602
# 3         4.0  735049          32.0          23.4    58.239788     1.315999
# 4         5.0  735049          31.4          21.9    56.174095     0.107639
# ...       ...     ...           ...           ...          ...          ...
# 7745     21.0  736571          23.1          17.8    24.688997    -1.385244
# 7746     22.0  736571          22.5          17.4    30.094858    -0.811158
# 7747     23.0  736571          23.3          17.1    26.741310    -1.328635
# 7748     24.0  736571          23.3          17.7    24.040634    -1.471468
# 7749     25.0  736571          23.2          17.4    22.933014    -1.475916
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  ...  LDAPS_PPT2  \
# 0            28.074101         -0.314003  0.097757  0.312316  ...   -0.519114
# 1            29.850689          0.142820 -0.622109 -0.209702  ...   -0.519114
# 2            30.091292          0.393133 -0.310859 -1.373795  ...   -0.519114
# 3            29.704629         -0.176064 -0.653345  0.206140  ...   -0.519114
# 4            29.113934         -0.105479 -0.590312  1.301881  ...   -0.519114
# ...                ...               ...       ...       ...  ...         ...
# 7745         27.812697         -1.967021 -0.024069 -1.940661  ...   -0.519114
# 7746         26.704905         -2.101124 -0.566181  0.658275  ...   -0.519114
# 7747         26.352081         -1.831058 -0.303861  0.385275  ...   -0.519114
# 7748         27.010193         -1.843442 -0.059415 -0.361066  ...   -0.519114
# 7749         27.939516         -1.904535  0.342301 -1.972680  ...   -0.519114
#
#       LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM     Slope  \
# 0      -0.492283   -0.444377  37.6046  126.991  1.834978  1.314153
# 1      -0.492283   -0.444377  37.6046  127.032  0.055979 -0.385336
# 2      -0.492283   -0.444377  37.5776  127.058 -0.364575 -0.949164
# 3      -0.492283   -0.444377  37.6450  127.022  0.084879  1.235263
# 4      -0.492283   -0.444377  37.5507  127.135 -0.290442 -0.401730
# ...          ...         ...      ...      ...       ...       ...
# 7745   -0.492283   -0.444377  37.5507  127.040 -0.721547 -0.279532
# 7746   -0.492283   -0.444377  37.5102  127.086 -1.006002 -1.354811
# 7747   -0.492283   -0.444377  37.5372  126.891 -1.578128 -1.280447
# 7748   -0.492283   -0.444377  37.5237  126.909 -1.400633 -1.072947
# 7749   -0.492283   -0.444377  37.5237  126.970 -1.193124 -0.935044
#
#       Solar radiation  Next_Tmax  Next_Tmin
# 0            1.849430       29.1       21.2
# 1            1.400702       30.5       22.5
# 2            1.380650       31.1       23.9
# 3            1.357783       31.7       24.3
# 4            1.366748       31.2       22.5
# ...               ...        ...        ...
# 7745        -1.738996       27.6       17.7
# 7746        -1.756451       28.0       17.1
# 7747        -1.754608       28.3       18.1
# 7748        -1.760631       28.6       18.8
# 7749        -1.744763       27.8       17.4
#
# [7642 rows x 25 columns]

# %%
# Checking the percentage of data loss -
loss = (temp.shape[0]-temp_new.shape[0])/temp.shape[0]*100
loss
# Out:
# 1.4189886480908152

# %%
x = temp_new.drop(["Next_Tmax","Next_Tmin"],axis=1)
y = temp_new["Next_Tmax"]
Y = temp_new["Next_Tmin"]
z = x.columns

print(x.shape)
print(y.shape)
print(Y.shape)
# Out:
# (7642, 23)
# (7642,)
# (7642,)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def vifscore(x):
    vif = pd.DataFrame()
    vif['Column Name'] = x.columns
    vif['VIF Factor'] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif.sort_values('VIF Factor',ascending = True))

# %%
vifscore(x)
# Out:
#          Column Name    VIF Factor
# 22   Solar radiation  1.241083e+00
# 8           LDAPS_WS  1.251858e+00
# 9           LDAPS_LH  1.499722e+00
# 16        LDAPS_PPT3  1.758982e+00
# 17        LDAPS_PPT4  1.784593e+00
# 15        LDAPS_PPT2  2.345888e+00
# 14        LDAPS_PPT1  2.595836e+00
# 5        LDAPS_RHmax  2.681444e+00
# 21             Slope  2.858756e+00
# 13         LDAPS_CC4  3.031812e+00
# 20               DEM  3.224573e+00
# 12         LDAPS_CC3  4.962996e+00
# 0            station  5.430583e+00
# 7   LDAPS_Tmin_lapse  6.340763e+00
# 10         LDAPS_CC1  1.511755e+01
# 11         LDAPS_CC2  1.773780e+01
# 4        LDAPS_RHmin  1.046071e+02
# 2       Present_Tmax  2.928016e+02
# 3       Present_Tmin  3.047759e+02
# 6   LDAPS_Tmax_lapse  7.209217e+02
# 18               lat  7.152610e+05
# 1               Date  1.262167e+06
# 19               lon  1.688449e+06

# %%
from sklearn.preprocessing import MinMaxScaler

sc=MinMaxScaler()
x = pd.DataFrame(x,columns = z)
x
# Out:
#       station    Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0  735049          28.7          21.4    58.255688     0.269762
# 1         2.0  735049          31.9          21.6    52.263397     0.182577
# 2         3.0  735049          31.6          23.3    48.690479    -0.776602
# 3         4.0  735049          32.0          23.4    58.239788     1.315999
# 4         5.0  735049          31.4          21.9    56.174095     0.107639
# ...       ...     ...           ...           ...          ...          ...
# 7745     21.0  736571          23.1          17.8    24.688997    -1.385244
# 7746     22.0  736571          22.5          17.4    30.094858    -0.811158
# 7747     23.0  736571          23.3          17.1    26.741310    -1.328635
# 7748     24.0  736571          23.3          17.7    24.040634    -1.471468
# 7749     25.0  736571          23.2          17.4    22.933014    -1.475916
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  ...  LDAPS_CC4  \
# 0            28.074101         -0.314003  0.097757  0.312316  ...  -0.580369
# 1            29.850689          0.142820 -0.622109 -0.209702  ...  -0.599240
# 2            30.091292          0.393133 -0.310859 -1.373795  ...  -0.515420
# 3            29.704629         -0.176064 -0.653345  0.206140  ...  -0.560937
# 4            29.113934         -0.105479 -0.590312  1.301881  ...  -0.360509
# ...                ...               ...       ...       ...  ...        ...
# 7745         27.812697         -1.967021 -0.024069 -1.940661  ...  -1.446711
# 7746         26.704905         -2.101124 -0.566181  0.658275  ...  -1.342567
# 7747         26.352081         -1.831058 -0.303861  0.385275  ...  -1.481793
# 7748         27.010193         -1.843442 -0.059415 -0.361066  ...  -1.481793
# 7749         27.939516         -1.904535  0.342301 -1.972680  ...  -1.475387
#
#       LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon  \
# 0      -0.557339   -0.519114   -0.492283   -0.444377  37.6046  126.991
# 1      -0.557339   -0.519114   -0.492283   -0.444377  37.6046  127.032
# 2      -0.557339   -0.519114   -0.492283   -0.444377  37.5776  127.058
# 3      -0.557339   -0.519114   -0.492283   -0.444377  37.6450  127.022
# 4      -0.557339   -0.519114   -0.492283   -0.444377  37.5507  127.135
# ...          ...         ...         ...         ...      ...      ...
# 7745   -0.557339   -0.519114   -0.492283   -0.444377  37.5507  127.040
# 7746   -0.557339   -0.519114   -0.492283   -0.444377  37.5102  127.086
# 7747   -0.557339   -0.519114   -0.492283   -0.444377  37.5372  126.891
# 7748   -0.557339   -0.519114   -0.492283   -0.444377  37.5237  126.909
# 7749   -0.557339   -0.519114   -0.492283   -0.444377  37.5237  126.970
#
#            DEM     Slope  Solar radiation
# 0     1.834978  1.314153         1.849430
# 1     0.055979 -0.385336         1.400702
# 2    -0.364575 -0.949164         1.380650
# 3     0.084879  1.235263         1.357783
# 4    -0.290442 -0.401730         1.366748
# ...        ...       ...              ...
# 7745 -0.721547 -0.279532        -1.738996
# 7746 -1.006002 -1.354811        -1.756451
# 7747 -1.578128 -1.280447        -1.754608
# 7748 -1.400633 -1.072947        -1.760631
# 7749 -1.193124 -0.935044        -1.744763
#
# [7642 rows x 23 columns]

# %%
#Model 
from sklearn.model_selection import train_test_split,GridSearchCV

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR

from sklearn.model_selection import cross_val_score

#Metrics 
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score

# %%
def random_st_tmax(model):
    max_score = 0
    max_rs = 0
    print('\n',model)
    for i in range(1,50):
        x_train, x_test,y_train,y_test= train_test_split(x,y,test_size = 0.20, random_state = i)
        model.fit(x_train,y_train)
        pred_test = model.predict(x_test)
        score = r2_score(y_test,pred_test)
        if score > max_score:
            max_score = score
            max_rs = i
    print("At random state ", max_rs, 'the model is having accuracy score of ', max_score)
    return max_rs

# %%
def model_fit_tmax(model, rs):
    x_train, x_test,y_train,y_test= train_test_split(x,y,test_size = 0.20, random_state = rs)
    model.fit(x_train,y_train)
    pred_test = model.predict(x_test)
    r2 = r2_score(y_test,pred_test)
    mse = mean_squared_error(y_test,pred_test)
    mae = mean_absolute_error(y_test,pred_test)
    cv_score = cross_val_score(model,x,y, cv = 8)
    cv_mean = cv_score.mean()
    print("\n R2 score is ", r2)
    print("-"*50)
    print("Mean Sqaured Error is ",mse)
    print("-"*50)
    print("Mean Absolute Error is ",mae)
    print("-"*50)
    print("The cv score is ", cv_mean, "and the R2 score  is ",r2)
    print(f'\n Difference between accuracy score and cross val score {(r2-cv_mean)*100:.2f}')
    print("-"*50)

# %%
def model_tmax(m):
    m_rs = random_st_tmax(m)
    model_fit_tmax(m,m_rs)

# %%
Model_regres = [LinearRegression(),RandomForestRegressor(),KNeighborsRegressor(),DecisionTreeRegressor(),GradientBoostingRegressor()]

# %%
for i in Model_regres:
    model_tmax(i)
# Out:
#  LinearRegression()
# At random state  30 the model is having accuracy score of  0.7790360812971816
#
#  R2 score is  0.7790360812971816
# --------------------------------------------------
# Mean Sqaured Error is  2.1487300000157665
# --------------------------------------------------
# Mean Absolute Error is  1.0995118325214461
# --------------------------------------------------
# The cv score is  0.6590170987691581 and the R2 score  is  0.7790360812971816
#
#  Difference between accuracy score and cross val score 12.00
# --------------------------------------------------
#
#  RandomForestRegressor()
# At random state  30 the model is having accuracy score of  0.9179247321137449
#
#  R2 score is  0.9186752618328492
# --------------------------------------------------
# Mean Sqaured Error is  0.7908300398953566
# --------------------------------------------------
# Mean Absolute Error is  0.6662007848266839
# --------------------------------------------------
# The cv score is  0.6507714337890895 and the R2 score  is  0.9186752618328492
#
#  Difference between accuracy score and cross val score 26.79
# --------------------------------------------------
#
#  KNeighborsRegressor()
# At random state  24 the model is having accuracy score of  0.8609698328039312
#
#  R2 score is  0.8609698328039312
# --------------------------------------------------
# Mean Sqaured Error is  1.3007644211903204
# --------------------------------------------------
# Mean Absolute Error is  0.8570045781556573
# --------------------------------------------------
# The cv score is  -0.979564857585302 and the R2 score  is  0.8609698328039312
#
#  Difference between accuracy score and cross val score 184.05
# --------------------------------------------------
#
#  DecisionTreeRegressor()
# At random state  32 the model is having accuracy score of  0.8071077946141304
#
#  R2 score is  0.811709954334447
# --------------------------------------------------
# Mean Sqaured Error is  1.6841661216481358
# --------------------------------------------------
# Mean Absolute Error is  0.9345323741007194
# --------------------------------------------------
# The cv score is  0.30900155392708684 and the R2 score  is  0.811709954334447
#
#  Difference between accuracy score and cross val score 50.27
# --------------------------------------------------
#
#  GradientBoostingRegressor()
# At random state  30 the model is having accuracy score of  0.8644002833715881
#
#  R2 score is  0.8643666231010398
# --------------------------------------------------
# Mean Sqaured Error is  1.3189461322787626
# --------------------------------------------------
# Mean Absolute Error is  0.8854471386979332
# --------------------------------------------------
# The cv score is  0.6910052953158682 and the R2 score  is  0.8643666231010398
#
#  Difference between accuracy score and cross val score 17.34
# --------------------------------------------------

# %% [markdown]
# Hyper Parameter Tuning

# %%
parameters = {'fit_intercept':[True, False],
             'normalize':[True, False],
             'copy_X' : [True, False],
             'n_jobs':list(range(1,10)),
             'positive':[True, False]}
grid_tmax= GridSearchCV(estimator=LinearRegression(),param_grid=parameters,cv = 8)

# %%
grid_tmax.fit(x,y)
# Out:
# GridSearchCV(cv=8, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'n_jobs': [1, 2, 3, 4, 5, 6, 7, 8, 9],
#                          'normalize': [True, False],
#                          'positive': [True, False]})

# %%
grid_tmax.best_score_
# Out:
# 0.6652972284546679

# %%
grid_tmax.best_params_
# Out:
# {'copy_X': True,
#  'fit_intercept': False,
#  'n_jobs': 1,
#  'normalize': True,
#  'positive': False}

# %%
final_model_tmax = LinearRegression(copy_X = True, fit_intercept =False,n_jobs = 1,normalize =True,positive=False)
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=24)
final_model_tmax.fit(x_train, y_train)
pred_test = final_model_tmax.predict(x_test)

print('R2 Score',r2_score(y_test,pred_test))
print('Mean Squared Error',mean_squared_error(y_test,pred_test))
print('Mean Absolute Error',mean_absolute_error(y_test,pred_test))
# Out:
# R2 Score 0.7680161897370572
# Mean Squared Error 2.1704374868272076
# Mean Absolute Error 1.112502120888317

# %%
# Saving the model
import joblib
joblib.dump(final_model_tmax,'TemperatureForecast-nextmax.pkl')
# Out:
# ['TemperatureForecast-nextmax.pkl']

# %%
load_model = joblib.load('TemperatureForecast-nextmax.pkl')
prediction = load_model.predict(x_test)
pd.DataFrame([load_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"]).T
# Out:
#       Predicted  Original
# 0     30.411193      30.6
# 1     32.004941      33.4
# 2     28.801536      29.4
# 3     28.548379      25.4
# 4     35.558986      35.7
# ...         ...       ...
# 1524  25.731514      23.6
# 1525  31.014862      31.2
# 1526  30.420211      33.5
# 1527  30.656809      30.2
# 1528  32.209229      33.2
#
# [1529 rows x 2 columns]

# %%
plt.figure(figsize = (8,8))
plt.scatter(x = y_test, y=prediction, color = 'r')
plt.plot(y_test, y_test, color = 'b')
plt.xlabel('Actual Value', fontsize = 14)
plt.ylabel('Predicted Value', fontsize = 14)
plt.title('Linear Regression', fontsize = 18)
plt.show()

# %% [markdown]
# #2 target variable nextmin

# %%
def random_st_tmin(model):
    max_score = 0
    max_rs = 0
    print('\n',model)
    for i in range(1,50):
        x_train, x_test,y_train,y_test= train_test_split(x,Y,test_size = 0.20, random_state = i)
        model.fit(x_train,y_train)
        pred_test = model.predict(x_test)
        score = r2_score(y_test,pred_test)
        if score > max_score:
            max_score = score
            max_rs = i
    print("At random state ", max_rs, 'the model is having accuracy score of ', max_score)
    return max_rs

# %%
def model_fit_tmin(model, rs):
    x_train, x_test,y_train,y_test= train_test_split(x,Y,test_size = 0.20, random_state = rs)
    model.fit(x_train,y_train)
    pred_test = model.predict(x_test)
    r2 = r2_score(y_test,pred_test)
    mse = mean_squared_error(y_test,pred_test)
    mae = mean_absolute_error(y_test,pred_test)
    cv_score = cross_val_score(model,x,Y, cv = 8)
    cv_mean = cv_score.mean()
    print("\n R2 score is ", r2)
    print("-"*50)
    print("Mean Sqaured Error is ",mse)
    print("-"*50)
    print("Mean Absolute Error is ",mae)
    print("-"*50)
    print("The cv score is ", cv_mean, "and the R2 score  is ",r2)
    print(f'\n Difference between accuracy score and cross val score {(r2-cv_mean)*100:.2f}')
    print("-"*50)

# %%
def model_tmin(m):
    m_rs = random_st_tmin(m)
    model_fit_tmin(m,m_rs)

# %%
for i in Model_regres:
    model_tmin(i)
# Out:
#  LinearRegression()
# At random state  24 the model is having accuracy score of  0.8345560567640163
#
#  R2 score is  0.8345560567640163
# --------------------------------------------------
# Mean Sqaured Error is  0.9758349963655322
# --------------------------------------------------
# Mean Absolute Error is  0.776428318402736
# --------------------------------------------------
# The cv score is  0.7543837274131602 and the R2 score  is  0.8345560567640163
#
#  Difference between accuracy score and cross val score 8.02
# --------------------------------------------------
#
#  RandomForestRegressor()
# At random state  44 the model is having accuracy score of  0.9113835311059164
#
#  R2 score is  0.9100383446356098
# --------------------------------------------------
# Mean Sqaured Error is  0.5123577527795943
# --------------------------------------------------
# Mean Absolute Error is  0.5410987573577498
# --------------------------------------------------
# The cv score is  0.7551474734439663 and the R2 score  is  0.9100383446356098
#
#  Difference between accuracy score and cross val score 15.49
# --------------------------------------------------
#
#  KNeighborsRegressor()
# At random state  22 the model is having accuracy score of  0.8171296800284941
#
#  R2 score is  0.8171296800284941
# --------------------------------------------------
# Mean Sqaured Error is  0.9934885546108567
# --------------------------------------------------
# Mean Absolute Error is  0.7777632439502944
# --------------------------------------------------
# The cv score is  -0.9629817797818535 and the R2 score  is  0.8171296800284941
#
#  Difference between accuracy score and cross val score 178.01
# --------------------------------------------------
#
#  DecisionTreeRegressor()
# At random state  10 the model is having accuracy score of  0.8036472453546091
#
#  R2 score is  0.8086485441976342
# --------------------------------------------------
# Mean Sqaured Error is  1.0937606278613474
# --------------------------------------------------
# Mean Absolute Error is  0.7823413996075869
# --------------------------------------------------
# The cv score is  0.4984279659254627 and the R2 score  is  0.8086485441976342
#
#  Difference between accuracy score and cross val score 31.02
# --------------------------------------------------
#
#  GradientBoostingRegressor()
# At random state  24 the model is having accuracy score of  0.8925518281252214
#
#  R2 score is  0.8925143843099124
# --------------------------------------------------
# Mean Sqaured Error is  0.633980448874303
# --------------------------------------------------
# Mean Absolute Error is  0.6263272574536323
# --------------------------------------------------
# The cv score is  0.7642973843988343 and the R2 score  is  0.8925143843099124
#
#  Difference between accuracy score and cross val score 12.82
# --------------------------------------------------

# %% [markdown]
# Hyper Parameter Tuning

# %%
parameters = {'fit_intercept':[True, False],
             'normalize':[True, False],
             'copy_X' : [True, False],
             'n_jobs':list(range(1,10)),
             'positive':[True, False]}
grid_tmin = GridSearchCV(estimator=LinearRegression(),param_grid=parameters,cv = 8)

# %%
grid_tmin.fit(x,Y)
# Out:
# GridSearchCV(cv=8, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'n_jobs': [1, 2, 3, 4, 5, 6, 7, 8, 9],
#                          'normalize': [True, False],
#                          'positive': [True, False]})

# %%
grid_tmin.best_params_
# Out:
# {'copy_X': True,
#  'fit_intercept': False,
#  'n_jobs': 1,
#  'normalize': True,
#  'positive': False}

# %%
final_model_tmin = LinearRegression(copy_X = True, fit_intercept =False,n_jobs = 1,normalize =True,positive=False)
x_train,x_test,y_train,y_test = train_test_split(x,Y,test_size=0.2,random_state=24)
final_model_tmin.fit(x_train, y_train)
pred_testmin = final_model_tmin.predict(x_test)

print('R2 Score',r2_score(y_test,pred_testmin))
print('Mean Squared Error',mean_squared_error(y_test,pred_testmin))
print('Mean Absolute Error',mean_absolute_error(y_test,pred_testmin))
# Out:
# R2 Score 0.8345895935012443
# Mean Squared Error 0.9756371872393061
# Mean Absolute Error 0.7762702077408092

# %%
# Saving the model

import joblib
joblib.dump(final_model_tmin,'TemperatureForecast-nextmin.pkl')
# Out:
# ['TemperatureForecast-nextmin.pkl']

# %%
load_model = joblib.load('TemperatureForecast-nextmin.pkl')
prediction_min = load_model.predict(x_test)
pd.DataFrame([load_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"]).T
# Out:
#       Predicted  Original
# 0     24.255081      25.3
# 1     27.286630      26.8
# 2     18.412269      18.8
# 3     23.610501      20.9
# 4     26.609005      26.2
# ...         ...       ...
# 1524  20.048214      19.8
# 1525  21.635693      23.2
# 1526  24.983156      26.2
# 1527  24.027031      22.9
# 1528  23.837419      24.7
#
# [1529 rows x 2 columns]

# %%
plt.figure(figsize = (8,8))
plt.scatter(x = y_test, y=prediction_min, color = 'r')
plt.plot(y_test, y_test, color = 'b')
plt.xlabel('Actual Value', fontsize = 14)
plt.ylabel('Predicted Value', fontsize = 14)
plt.title('Linear Regression', fontsize = 18)
plt.show()
